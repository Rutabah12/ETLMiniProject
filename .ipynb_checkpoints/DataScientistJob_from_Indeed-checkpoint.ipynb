# %%
import pandas as pd

# %%
from splinter import Browser
from bs4 import BeautifulSoup
import time

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless= False)

# %%
url = "https://www.indeed.com/jobs?q=data+scientist&l="
browser.visit(url)
time.sleep(1)

# %%
job_data = []
counter=0
scraping = True
while scraping == True:
    time.sleep(1)
    counter = counter+1
    print(f"COUNTER: {counter}")
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    jobs = soup.find_all("div", class_ = "jobsearch-SerpJobCard")

    for job in jobs:
        job_info = {}
        job_info["title"] = job.find("div", class_="title").a["title"]
        try:
            job_info["salary"] = job.find("div", class_ = "salarySnippet").text
        except:
            job_info["salary"] = "Unknown"
        try:
            job_info["location"] = job.find("div", class_="recJobLoc")["data-rc-loc"]
        except:
            job_info["location"] = "Unknown"
        try:
            job_info["company"] = job.find("span", class_="company").text
        except:
            job_info["company"] = "Unknown"
        job_data.append(job_info)
    try:
        print(browser.find_by_css(".np").last.text.lower())
        if "next" in browser.find_by_css(".np").last.text.lower():
            try:
                browser.find_by_css("#popover-x").click()
            except:
                 pass
            print(browser.find_by_css(".np").last.text.lower())
            browser.find_by_css(".np").last.click()
            time.sleep(1)
            print("next clicked")
        else:
            browser.find_by_css("#popover-x").click()
            scraping = False
    except:
        try:
            if browser.is_element_present_by_id("popover-x"):
                browser.find_by_css("#popover-x").click()
            else:
                scraping=False
        except:
             pass
print(job_data)
# Out:
# COUNTER: 1
# next »
# next »
# next clicked
# COUNTER: 2
# next »
# next »
# next clicked
# COUNTER: 3
# next »
# next »
# next clicked
# COUNTER: 4
# next »
# next »
# next clicked
# COUNTER: 5
# next »
# next »
# next clicked
# COUNTER: 6
# next »
# next »
# next clicked
# COUNTER: 7
# next »
# next »
# next clicked
# COUNTER: 8
# next »
# next »
# next clicked
# COUNTER: 9
# next »
# next »
# next clicked
# COUNTER: 10
# next »
# next »
# next clicked
# COUNTER: 11
# next »
# next »
# next clicked
# COUNTER: 12
# next »
# next »
# next clicked
# COUNTER: 13
# next »
# next »
# next clicked
# COUNTER: 14
# next »
# next »
# next clicked
# COUNTER: 15
# next »
# next »
# next clicked
# COUNTER: 16
# next »
# next »
# next clicked
# COUNTER: 17
# next »
# next »
# next clicked
# COUNTER: 18
# next »
# next »
# next clicked
# COUNTER: 19
# next »
# next »
# next clicked
# COUNTER: 20
# next »
# next »
# next clicked
# COUNTER: 21
# next »
# next »
# next clicked
# COUNTER: 22
# next »
# next »
# next clicked
# COUNTER: 23
# next »
# next »
# next clicked
# COUNTER: 24
# next »
# next »
# next clicked
# COUNTER: 25
# next »
# next »
# next clicked
# COUNTER: 26
# next »
# next »
# next clicked
# COUNTER: 27
# next »
# next »
# next clicked
# COUNTER: 28
# next »
# next »
# next clicked
# COUNTER: 29
# next »
# next »
# next clicked
# COUNTER: 30
# next »
# next »
# next clicked
# COUNTER: 31
# next »
# next »
# next clicked
# COUNTER: 32
# next »
# next »
# next clicked
# COUNTER: 33
# next »
# next »
# next clicked
# COUNTER: 34
# next »
# next »
# next clicked
# COUNTER: 35
# next »
# next »
# next clicked
# COUNTER: 36
# next »
# next »
# next clicked
# COUNTER: 37
# next »
# next »
# next clicked
# COUNTER: 38
# next »
# next »
# next clicked
# COUNTER: 39
}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Austin, TX', 'company': '\n        NarrativeDx'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Seattle, WA', 'company': '\n\n        red violet'}, {'title': 'Data Scientist - Sports', 'salary': '\n\n\n                            $80,000 - $110,000 a year\n\n', 'location': 'Austin, TX', 'company': '\n        Zelus Analytics'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Cincinnati, OH', 'company': '\n\n        Cincinnati Reds'}, {'title': 'Junior Data Scientist - Client Technical Specialist', 'salary': '\n\n\n                            $70,000 - $110,000 a year\n\n', 'location': 'Austin, TX', 'company': '\n\n        IBM'}, {'title': 'Full Time Opportunities for Students or Recent Graduates: Data & Applied Sciences', 'salary': 'Unknown', 'location': 'Redmond, WA', 'company': '\n\n        Microsoft'}, {'title': 'Entry Level Data Scientist', 'salary': 'Unknown', 'location': 'United States', 'company': '\n\n        IBM'}, {'title': 'Data Scientist (Jr)', 'salary': '\n\n\n                            $70,000 a year\n\n', 'location': 'Herndon, VA', 'company': '\n        Numero Data LLC'}, {'title': 'Junior Data Scientist - New York City', 'salary': '\n\n\n                            $80,000 - $120,000 a year\n\n', 'location': 'New York, NY', 'company': '\n\n        IBM'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Austin, TX', 'company': '\n\n        Oracle'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $130,000 - $165,000 a year\n\n', 'location': 'Remote', 'company': '\n        Skylight'}, {'title': 'Data Scientist - Entry Level', 'salary': 'Unknown', 'location': 'Sacramento, CA', 'company': '\n        Numerdox'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'San Francisco, CA', 'company': '\n        BestReviews'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Chicago, IL', 'company': '\n        Seen by Indeed'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $67,968 - $126,062 a year\n\n', 'location': 'Washington, DC', 'company': '\n\n        Central Intelligence Agency'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Conshohocken, PA', 'company': '\n        OptivityX,LLC'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $99,172 - $152,352 a year\n\n', 'location': 'Fort Meade, MD', 'company': '\n\n        National Security Agency'}, {'title': 'Senior Data Scientist', 'salary': '\n\n\n                            Up to $160,000 a year\n\n', 'location': 'Los Angeles, CA', 'company': '\n\n        Just Auto Insurance'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Denver, CO', 'company': '\n        Valen Analytics'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Granite City, IL', 'company': '\n\n        Amsted Rail Company Inc.'}, {'title': 'Undergraduate Internship/Co-op Program - Data Scientist', 'salary': '\n\n\n                            $21.93 - $26.43 an hour\n\n', 'location': 'Washington, DC', 'company': '\n\n        Central Intelligence Agency'}, {'title': 'Data Classification Specialist', 'salary': '\n\n\n                            $18 an hour\n\n', 'location': 'St. Louis, MO', 'company': '\n        Idiomatic'}, {'title': 'Entry Level - Associate Data Scientist', 'salary': 'Unknown', 'location': 'United States', 'company': '\n\n         ...

# %%
data_scientist_job_df = pd.DataFrame(job_data)
data_scientist_job_df
# Out:
#                                          company             location  \
# 0                   \n\n        Valassis Digital      Morrisville, NC
# 1     \n        Capital Lighting Fixture Company   Flowery Branch, GA
# 2              \n\n        Echo Global Logistics          Chicago, IL
# 3       \n        TechMileage Software Solutions       Long Beach, CA
# 4                          \n        NarrativeDx           Austin, TX
# 5                         \n\n        red violet          Seattle, WA
# 6                      \n        Zelus Analytics           Austin, TX
# 7                    \n\n        Cincinnati Reds       Cincinnati, OH
# 8                                \n\n        IBM           Austin, TX
# 9                          \n\n        Microsoft          Redmond, WA
# 10                               \n\n        IBM        United States
# 11                     \n        Numero Data LLC          Herndon, VA
# 12                               \n\n        IBM         New York, NY
# 13                            \n\n        Oracle           Austin, TX
# 14                            \n        Skylight               Remote
# 15                            \n        Numerdox       Sacramento, CA
# 16                         \n        BestReviews    San Francisco, CA
# 17                      \n        Seen by Indeed          Chicago, IL
# 18       \n\n        Central Intelligence Agency       Washington, DC
# 19                       \n        OptivityX,LLC     Conshohocken, PA
# 20          \n\n        National Security Agency       Fort Meade, MD
# 21               \n\n        Just Auto Insurance      Los Angeles, CA
# 22                     \n        Valen Analytics           Denver, CO
# 23          \n\n        Amsted Rail Company Inc.     Granite City, IL
# 24       \n\n        Central Intelligence Agency       Washington, DC
# 25                           \n        Idiomatic        St. Louis, MO
# 26                               \n\n        IBM        United States
# 27                     \n        Zelus Analytics           Austin, TX
# 28                     \n\n        ClosedLoop.ai           Austin, TX
# 29                             \n\n        Apple           Austin, TX
# ...                                          ...                  ...
# 1560                          \n        SaaSpack      Foster City, CA
# 1561                  \n        Capax Global LLC          Chicago, IL
# 1562           \n        Leading Path Consulting           Reston, VA
# 1563                \n\n        Marlette Funding           Newark, CA
# 1564       \n\n        Symphony Health Solutions        United States
# 1565                            \n        Acorns           Irvine, CA
# 1566  \n\n        Innovations for Poverty Action         New York, NY
# 1567               \n\n        Fractal Analytics    San Francisco, CA
# 1568     \n\n        Central Intelligence Agency       Washington, DC
# 1569                     \n\n        Campus Labs          Buffalo, NY
# 1570                       \n\n        eBay Inc.         San Jose, CA
# 1571                       \n\n        eBay Inc.    San Francisco, CA
# 1572       \n\n        Disney Streaming Services         New York, NY
# 1573    \n        Technical Recruiting Solutions        Lafayette, IN
# 1574                        \n\n        Facebook       Menlo Park, CA
# 1575                      \n        WTS Paradigm         Montreal, WI
# 1576                         \n        Techprofy          Atlanta, GA
# 1577                   \n\n        Trinity Solar  Monmouth County, NJ
# 1578                    \n        Seen by Indeed          Chicago, IL
# 1579                           \n\n        Tesla          Seattle, WA
# 1580                          \n\n        U-Haul          Phoenix, AZ
# 1581                 \n\n        CGI Group, Inc.       Birmingham, AL
# 1582                          \n\n        Unisys         Sterling, VA
# 1583        \n\n        Amsted Rail Company Inc.     Granite City, IL
# 1584                       \n\n        eBay Inc.    San Francisco, CA
# 1585                              \n\n        BD           Boston, MA
# 1586                       \n\n        Perspecta       Washington, DC
# 1587                          \n\n        Indeed           Austin, TX
# 1588                \n        ASR Analytics, LLC       Washington, DC
# 1589                        \n\n        Deloitte          Chicago, IL
#
#                                                  salary  \
# 0                                               Unknown
# 1                                               Unknown
# 2                                               Unknown
# 3                                               Unknown
# 4                                               Unknown
# 5                                               Unknown
# 6     \n\n\n                            $80,000 - $1...
# 7                                               Unknown
# 8     \n\n\n                            $70,000 - $1...
# 9                                               Unknown
# 10                                              Unknown
# 11    \n\n\n                            $70,000 a ye...
# 12    \n\n\n                            $80,000 - $1...
# 13                                              Unknown
# 14    \n\n\n                            $130,000 - $...
# 15                                              Unknown
# 16                                              Unknown
# 17                                              Unknown
# 18    \n\n\n                            $67,968 - $1...
# 19                                              Unknown
# 20    \n\n\n                            $99,172 - $1...
# 21    \n\n\n                            Up to $160,0...
# 22                                              Unknown
# 23                                              Unknown
# 24    \n\n\n                            $21.93 - $26...
# 25    \n\n\n                            $18 an hour\n\n
# 26                                              Unknown
# 27    \n\n\n                            $110,000 - $...
# 28                                              Unknown
# 29                                              Unknown
# ...                                                 ...
# 1560  \n\n\n                            $70 - $80 an...
# 1561                                            Unknown
# 1562  \n\n\n                            $150,000 - $...
# 1563                                            Unknown
# 1564                                            Unknown
# 1565                                            Unknown
# 1566                                            Unknown
# 1567                                            Unknown
# 1568  \n\n\n                            $21.93 - $26...
# 1569                                            Unknown
# 1570                                            Unknown
# 1571                                            Unknown
# 1572                                            Unknown
# 1573  \n\n\n                            $70,000 - $1...
# 1574                                            Unknown
# 1575                                            Unknown
# 1576  \n\n\n                            $50 - $60 an...
# 1577                                            Unknown
# 1578                                            Unknown
# 1579                                            Unknown
# 1580  \n\n\n                            $75,000 - $1...
# 1581                                            Unknown
# 1582                                            Unknown
# 1583                                            Unknown
# 1584                                            Unknown
# 1585                                            Unknown
# 1586                                            Unknown
# 1587  \n\n\n                            $130,000 - $...
# 1588                                            Unknown
# 1589                                            Unknown
#
#                                                   title
# 0                                        Data Scientist
# 1                                        Data Scientist
# 2                                        Data Scientist
# 3                                        Data Scientist
# 4                                        Data Scientist
# 5                                        Data Scientist
# 6                               Data Scientist - Sports
# 7                                        Data Scientist
# 8     Junior Data Scientist - Client Technical Speci...
# 9     Full Time Opportunities for Students or Recent...
# 10                           Entry Level Data Scientist
# 11                                  Data Scientist (Jr)
# 12                Junior Data Scientist - New York City
# 13                                       Data Scientist
# 14                                       Data Scientist
# 15                         Data Scientist - Entry Level
# 16                                       Data Scientist
# 17                                       Data Scientist
# 18                                       Data Scientist
# 19                                       Data Scientist
# 20                                       Data Scientist
# 21                                Senior Data Scientist
# 22                                       Data Scientist
# 23                                       Data Scientist
# 24    Undergraduate Internship/Co-op Program - Data ...
# 25                       Data Classification Specialist
# 26               Entry Level - Associate Data Scientist
# 27                       Senior Data Scientist - Sports
# 28                            Healthcare Data Scientist
# 29            Data Scientist - Applied Machine Learning
# ...                                                 ...
# 1560                                Lead Data Scientist
# 1561                                     Data Scientist
# 1562                             Cleared Data Scientist
# 1563                                     Data Scientist
# 1564                              Senior Data Scientist
# 1565                                     Data Scientist
# 1566                              Global Data Scientist
# 1567        Data Scientist (Banking/Financial Services)
# 1568  Undergraduate Internship/Co-op Program - Data ...
# 1569                                     Data Scientist
# 1570                                   Data Scientist 1
# 1571                    Revenue Modeling Data Scientist
# 1572                          Data Scientist - Modeling
# 1573                            Data Scientist (Python)
# 1574                                Data Scientist, SBG
# 1575  Data/AI Scientist - Spécialiste données et int...
# 1576                                     Data Scientist
# 1577                                     Data Scientist
# 1578                                     Data Scientist
# 1579           Data Scientist/Machine Learning Engineer
# 1580                                     Data Scientist
# 1581                                     Data Scientist
# 1582                                     Data Scientist
# 1583                                     Data Scientist
# 1584                  Data Scientist, Product Analytics
# 1585                                     Data Scientist
# 1586                                     Data Scientist
# 1587     Senior Data Scientist, Product - Resume Search
# 1588   Data Scientist / Developer (Junior to Mid-Level)
# 1589                               Data Scientist - Hux
#
# [1590 rows x 4 columns]

# %%
data_scientist_job_df.to_csv("datascientistjobdata.csv", index=False)
