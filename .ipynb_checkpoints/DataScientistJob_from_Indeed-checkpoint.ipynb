# %%
import pandas as pd

# %%
from splinter import Browser
from bs4 import BeautifulSoup
import time

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless= False)

# %%
url = "https://www.indeed.com/jobs?q=data+scientist&l="
browser.visit(url)
time.sleep(1)

# %%
job_data = []
counter=0
scraping = True
while scraping == True:
    time.sleep(1)
    counter = counter+1
    print(f"COUNTER: {counter}")
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    jobs = soup.find_all("div", class_ = "jobsearch-SerpJobCard")

    for job in jobs:
        job_info = {}
        job_info["title"] = job.find("div", class_="title").a["title"]
        try:
            job_info["salary"] = job.find("div", class_ = "salarySnippet").text
        except:
            job_info["salary"] = "Unknown"
        try:
            job_info["location"] = job.find("div", class_="recJobLoc")["data-rc-loc"]
        except:
            job_info["location"] = "Unknown"
        try:
            job_info["company"] = job.find("span", class_="company").text
        except:
            job_info["company"] = "Unknown"
        job_data.append(job_info)
    try:
        print(browser.find_by_css(".np").last.text.lower())
        if "next" in browser.find_by_css(".np").last.text.lower():
            print(browser.find_by_css(".np").last.text.lower())
            browser.find_by_css(".np").last.click()
            time.sleep(1)
            print("next clicked")
        else:
            browser.find_by_css("#popover-x").click()
            scraping = False
    except:
        try:
            if browser.is_element_present_by_id("popover-x"):
                browser.find_by_css("#popover-x").click()
            else:
                scraping=False
        except:
             pass
print(job_data)
# Out:
# COUNTER: 1
# next »
# next »
# next clicked
# COUNTER: 2
# next »
# next »
# COUNTER: 3
# next »
# next »
# next clicked
# COUNTER: 4
# next »
# next »
# next clicked
# COUNTER: 5
# next »
# next »
# next clicked
# COUNTER: 6
# next »
# next »
# next clicked
# COUNTER: 7
# next »
# next »
# next clicked
# COUNTER: 8
# next »
# next »
# next clicked
# COUNTER: 9
# next »
# next »
# next clicked
# COUNTER: 10
# next »
# next »
# next clicked
# COUNTER: 11
# next »
# next »
# next clicked
# COUNTER: 12
# next »
# next »
# next clicked
# COUNTER: 13
# next »
# next »
# next clicked
# COUNTER: 14
# next »
# next »
# next clicked
# COUNTER: 15
# next »
# next »
# next clicked
# COUNTER: 16
# next »
# next »
# next clicked
# COUNTER: 17
# next »
# next »
# next clicked
# COUNTER: 18
# next »
# next »
# next clicked
# COUNTER: 19
# next »
# next »
# next clicked
# COUNTER: 20
# next »
# next »
# next clicked
# COUNTER: 21
# next »
# next »
# next clicked
# COUNTER: 22
# next »
# next »
# next clicked
# COUNTER: 23
# next »
# next »
# next clicked
# COUNTER: 24
# next »
# next »
# next clicked
# COUNTER: 25
# next »
# next »
# next clicked
# COUNTER: 26
# next »
# next »
# next clicked
# COUNTER: 27
# next »
# next »
# next clicked
# COUNTER: 28
# next »
# next »
# next clicked
# COUNTER: 29
# next »
# next »
# next clicked
# COUNTER: 30
# next »
# next »
# next clicked
# COUNTER: 31
# next »
# next »
# next clicked
# COUNTER: 32
# next »
# next »
# next clicked
# COUNTER: 33
# next »
# next »
# next clicked
# COUNTER: 34
# next »
# next »
# next clicked
# COUNTER: 35
# next »
# next »
# next clicked
# COUNTER: 36
# next »
# next »
# next clicked
# COUNTER: 37
# next »
# next »
# next clicked
# COUNTER: 38
# next »
# next »
# next clicked
# COUNTER: 39
# next »
# next »
# next clicked
# COUNTER: 40
# next »
# next »
# next clicked
# COUNTER: 41
# next »
# next »
# next clicked
# COUNTER: 42
# next »
# next »
# next clicked
# COUNTER: 43
# next »
# next »
# next clicked
# COUNTER: 44
# next »
# next »
# next clicked
# COUNTER: 45
# next »
# next »
# next clicked
# COUNTER: 46
# next »
# next »
# next clicked
# COUNTER: 47
# next »
# next »
# next clicked
# COUNTER: 48
# next »
# next »
# next clicked
# COUNTER: 49
# next »
# next »
# next clicked
# COUNTER: 50
# next »
# next »
# next clicked
# COUNTER: 51
# next »
# next »
# next clicked
# COUNTER: 52
# next »
# next »
# next clicked
# COUNTER: 53
# next »
# next »
# next clicked
# COUNTER: 54
# next »
# next »
# next clicked
# COUNTER: 55
# next »
# next »
# next clicked
# COUNTER: 56
# next »
# next »
# next clicked
# COUNTER: 57
# next »
# next »
# next clicked
# COUNTER: 58
# next »
# next »
# next clicked
# COUNTER: 59
# next »
# next »
# next clicked
# COUNTER: 60
# next »
# next »
# next clicked
# COUNTER: 61
# next »
# next »
# next clicked
# COUNTER: 62
# next »
# next »
# next clicked
# COUNTER: 63
# next »
# next »
# next clicked
# COUNTER: 64
# next »
# next »
# next clicked
# COUNTER: 65
# next »
# next »
# next clicked
# COUNTER: 66
# next »
# next »
# next clicked
# COUNTER: 67
# next »
# next »
# next clicked
# COUNTER: 68
# next »
# next »
# next clicked
# COUNTER: 69
# next »
# next »
# next clicked
# COUNTER: 70
# next »
# next »
# next clicked
# COUNTER: 71
# next »
# next »
# next clicked
# COUNTER: 72
# next »
# next »
# next clicked
# COUNTER: 73
# next »
# next »
# next clicked
# COUNTER: 74
# next »
# next »
# next clicked
# COUNTER: 75
# next »
# next »
# next clicked
# COUNTER: 76
# next »
# next »
# next clicked
# COUNTER: 77
# next »
# next »
# next clicked
# COUNTER: 78
# next »
# next »
# next clicked
# COUNTER: 79
# next »
# next »
# next clicked
# COUNTER: 80
# next »
# next »
# next clicked
# COUNTER: 81
# next »
# next »
# next clicked
# COUNTER: 82
# next »
# next »
# next clicked
# COUNTER: 83
# next »
# next »
# next clicked
# COUNTER: 84
# next »
# next »
# next clicked
# COUNTER: 85
# next »
# next »
# next clicked
# COUNTER: 86
# next »
# next »
# next clicked
# COUNTER: 87
# next »
# next »
# next clicked
# COUNTER: 88
# next »
# next »
# next clicked
# COUNTER: 89
# next »
# next »
# next clicked
# COUNTER: 90
# next »
# next »
# next clicked
# COUNTER: 91
# next »
# next »
# next clicked
# COUNTER: 92
# next »
# next »
# next clicked
# COUNTER: 93
# next »
# next »
# next clicked
# COUNTER: 94
# next »
# next »
# next clicked
# COUNTER: 95
# next »
# next »
# next clicked
# COUNTER: 96
# next »
# next »
# next clicked
# COUNTER: 97
# next »
# next »
# next clicked
# COUNTER: 98
# next »
# next »
# next clicked
# COUNTER: 99
# next »
# next »
# next clicked
# COUNTER: 100
# next »
# next »
# next clicked
# COUNTER: 101
# « previous
# [{'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Morrisville, NC', 'company': '\n\n        Valassis Digital'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'San Francisco, CA', 'company': '\n        BestReviews'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $67,968 - $126,062 a year\n\n', 'location': 'Washington, DC', 'company': '\n\n        Central Intelligence Agency'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Seattle, WA', 'company': '\n\n        red violet'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Chicago, IL', 'company': '\n\n        Echo Global Logistics'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Aurora, CO', 'company': '\n\n        UCHealth'}, {'title': 'Data Scientist - Sports', 'salary': '\n\n\n                            $80,000 - $110,000 a year\n\n', 'location': 'Austin, TX', 'company': '\n        Zelus Analytics'}, {'title': 'Junior Data Scientist - Client Technical Specialist', 'salary': '\n\n\n                            $70,000 - $110,000 a year\n\n', 'location': 'Austin, TX', 'company': '\n\n        IBM'}, {'title': 'Entry Level Data Scientist', 'salary': 'Unknown', 'location': 'United States', 'company': '\n\n        IBM'}, {'title': 'Full Time Opportunities for Students or Recent Graduates: Data & Applied Sciences', 'salary': 'Unknown', 'location': 'Redmond, WA', 'company': '\n\n        Microsoft'}, {'title': 'Junior Data Scientist - New York City', 'salary': '\n\n\n                            $80,000 - $120,000 a year\n\n', 'location': 'New York, NY', 'company': '\n\n        IBM'}, {'title': 'Data Scientist (Jr)', 'salary': '\n\n\n                            $70,000 a year\n\n', 'location': 'Herndon, VA', 'company': '\n        Numero Data LLC'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Austin, TX', 'company': '\n\n        Oracle'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Cincinnati, OH', 'company': '\n\n        Cincinnati Reds'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $130,000 - $165,000 a year\n\n', 'location': 'Remote', 'company': '\n        Skylight'}, {'title': 'Data Scientist - Entry Level', 'salary': 'Unknown', 'location': 'Sacramento, CA', 'company': '\n        Numerdox'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Austin, TX', 'company': '\n        NarrativeDx'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Chicago, IL', 'company': '\n        Seen by Indeed'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $99,172 - $152,352 a year\n\n', 'location': 'Fort Meade, MD', 'company': '\n\n        National Security Agency'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Boston, MA', 'company': '\n\n        BD'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Saint Paul, MN', 'company': '\n\n        Mille Lacs Corporate Ventures'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Miami Lakes, FL', 'company': '\n\n        BankUnited'}, {'title': 'Data Scientist', 'salary': 'Unknown', 'location': 'Denver, CO', 'company': '\n        Valen Analytics'}, {'title': 'Data Scientist 1', 'salary': 'Unknown', 'location': 'San Jose, CA', 'company': '\n\n        eBay Inc.'}, {'title': 'Data Scientist', 'salary': '\n\n\n                            $100,000 - $130,000 a year\n\n', 'location': 'Seattle, WA', 'company': '\n\n        Abstract Tokenization'}, {'title': 'Entry Level - Associate Data Scientist', 'salary': 'Unknown', 'location': 'United States', 'company': '\n\n        IBM'}, {'title': 'Data Scientist - Applied Machine Learning', 'salary': 'Unknown', 'location': 'Austin, TX', 'company': '\n\n        Apple'}, {'title': 'Data Classification Specialist', 'salary': '\n\n\n                            $18 an hour\n\n', 'location': 'St. Louis, MO', 'company': '\n        Idiomatic'}, {'title': 'Data Scientist', 'salar ...

# %%
data_scientist_job_df = pd.DataFrame(job_data)
data_scientist_job_df
# Out:
#                                                 company  \
# 0                          \n\n        Valassis Digital
# 1                                 \n        BestReviews
# 2               \n\n        Central Intelligence Agency
# 3                                \n\n        red violet
# 4                     \n\n        Echo Global Logistics
# 5                                  \n\n        UCHealth
# 6                             \n        Zelus Analytics
# 7                                       \n\n        IBM
# 8                                       \n\n        IBM
# 9                                 \n\n        Microsoft
# 10                                      \n\n        IBM
# 11                            \n        Numero Data LLC
# 12                                   \n\n        Oracle
# 13                          \n\n        Cincinnati Reds
# 14                                   \n        Skylight
# 15                                   \n        Numerdox
# 16                                \n        NarrativeDx
# 17                             \n        Seen by Indeed
# 18                 \n\n        National Security Agency
# 19                                       \n\n        BD
# 20            \n\n        Mille Lacs Corporate Ventures
# 21                               \n\n        BankUnited
# 22                            \n        Valen Analytics
# 23                                \n\n        eBay Inc.
# 24                    \n\n        Abstract Tokenization
# 25                                      \n\n        IBM
# 26                                    \n\n        Apple
# 27                                  \n        Idiomatic
# 28              \n\n        LOCKHEED MARTIN CORPORATION
# 29                  \n\n        Customer Value Partners
# ...                                                 ...
# 1561                                 \n        Blue Owl
# 1562                            \n        Power Factors
# 1563                                            Unknown
# 1564                     \n\n        Riverside Research
# 1565                        \n\n        Swing Education
# 1566      \n\n        MedStar Health Research Institute
# 1567                    \n\n        Corteva Agriscience
# 1568                                 \n        aspirent
# 1569                           \n        Tropikia Group
# 1570                             \n\n        TXU Energy
# 1571                                \n\n        Walmart
# 1572                   \n\n        Simon Property Group
# 1573                \n\n        RAYMOND JAMES FINANCIAL
# 1574                       \n\n        Definitive Logic
# 1575                       \n\n        Purchasing Power
# 1576                \n\n        The Climate Corporation
# 1577                         \n\n        Cotiviti, Inc.
# 1578                      \n        DESE Research, Inc.
# 1579                         \n        LVIS Corporation
# 1580                 \n\n        Root Insurance Company
# 1581  \n        BrightSpeed is a trademark of Bright...
# 1582                                 \n\n        Revlon
# 1583                             \n\n        ExxonMobil
# 1584                                  \n\n        Hinge
# 1585                                   \n\n        AT&T
# 1586                           \n\n        The Hartford
# 1587                                  \n\n        Tesla
# 1588                   \n        Eclipse Gaming Systems
# 1589                                  \n\n        Porch
# 1590                               \n\n        Deloitte
#
#                       location  \
# 0              Morrisville, NC
# 1            San Francisco, CA
# 2               Washington, DC
# 3                  Seattle, WA
# 4                  Chicago, IL
# 5                   Aurora, CO
# 6                   Austin, TX
# 7                   Austin, TX
# 8                United States
# 9                  Redmond, WA
# 10                New York, NY
# 11                 Herndon, VA
# 12                  Austin, TX
# 13              Cincinnati, OH
# 14                      Remote
# 15              Sacramento, CA
# 16                  Austin, TX
# 17                 Chicago, IL
# 18              Fort Meade, MD
# 19                  Boston, MA
# 20              Saint Paul, MN
# 21             Miami Lakes, FL
# 22                  Denver, CO
# 23                San Jose, CA
# 24                 Seattle, WA
# 25               United States
# 26                  Austin, TX
# 27               St. Louis, MO
# 28              Fort Worth, TX
# 29              Washington, DC
# ...                        ...
# 1561         San Francisco, CA
# 1562              Larkspur, CA
# 1563              Franklin, TN
# 1564  Wright-Patterson AFB, OH
# 1565             San Mateo, CA
# 1566            Washington, DC
# 1567              Johnston, IA
# 1568               Atlanta, GA
# 1569              New York, NY
# 1570                Irving, TX
# 1571             Sunnyvale, CA
# 1572              New York, NY
# 1573      Saint Petersburg, FL
# 1574             Arlington, VA
# 1575               Atlanta, GA
# 1576             St. Louis, MO
# 1577               Atlanta, GA
# 1578            Huntsville, AL
# 1579             Palo Alto, CA
# 1580              Columbus, OH
# 1581            Palm Coast, FL
# 1582              New York, NY
# 1583                Spring, TX
# 1584              New York, NY
# 1585          Collinsville, IL
# 1586              Hartford, CT
# 1587               Seattle, WA
# 1588               Atlanta, GA
# 1589               Seattle, WA
# 1590               Raleigh, NC
#
#                                                  salary  \
# 0                                               Unknown
# 1                                               Unknown
# 2     \n\n\n                            $67,968 - $1...
# 3                                               Unknown
# 4                                               Unknown
# 5                                               Unknown
# 6     \n\n\n                            $80,000 - $1...
# 7     \n\n\n                            $70,000 - $1...
# 8                                               Unknown
# 9                                               Unknown
# 10    \n\n\n                            $80,000 - $1...
# 11    \n\n\n                            $70,000 a ye...
# 12                                              Unknown
# 13                                              Unknown
# 14    \n\n\n                            $130,000 - $...
# 15                                              Unknown
# 16                                              Unknown
# 17                                              Unknown
# 18    \n\n\n                            $99,172 - $1...
# 19                                              Unknown
# 20                                              Unknown
# 21                                              Unknown
# 22                                              Unknown
# 23                                              Unknown
# 24    \n\n\n                            $100,000 - $...
# 25                                              Unknown
# 26                                              Unknown
# 27    \n\n\n                            $18 an hour\n\n
# 28                                              Unknown
# 29                                              Unknown
# ...                                                 ...
# 1561  \n\n\n                            $200,000 - $...
# 1562                                            Unknown
# 1563                                            Unknown
# 1564                                            Unknown
# 1565                                            Unknown
# 1566                                            Unknown
# 1567                                            Unknown
# 1568                                            Unknown
# 1569                                            Unknown
# 1570                                            Unknown
# 1571                                            Unknown
# 1572                                            Unknown
# 1573                                            Unknown
# 1574                                            Unknown
# 1575                                            Unknown
# 1576                                            Unknown
# 1577                                            Unknown
# 1578                                            Unknown
# 1579                                            Unknown
# 1580                                            Unknown
# 1581                                            Unknown
# 1582                                            Unknown
# 1583                                            Unknown
# 1584                                            Unknown
# 1585                                            Unknown
# 1586                                            Unknown
# 1587                                            Unknown
# 1588                                            Unknown
# 1589                                            Unknown
# 1590                                            Unknown
#
#                                                   title
# 0                                        Data Scientist
# 1                                        Data Scientist
# 2                                        Data Scientist
# 3                                        Data Scientist
# 4                                        Data Scientist
# 5                                        Data Scientist
# 6                               Data Scientist - Sports
# 7     Junior Data Scientist - Client Technical Speci...
# 8                            Entry Level Data Scientist
# 9     Full Time Opportunities for Students or Recent...
# 10                Junior Data Scientist - New York City
# 11                                  Data Scientist (Jr)
# 12                                       Data Scientist
# 13                                       Data Scientist
# 14                                       Data Scientist
# 15                         Data Scientist - Entry Level
# 16                                       Data Scientist
# 17                                       Data Scientist
# 18                                       Data Scientist
# 19                                       Data Scientist
# 20                                       Data Scientist
# 21                                       Data Scientist
# 22                                       Data Scientist
# 23                                     Data Scientist 1
# 24                                       Data Scientist
# 25               Entry Level - Associate Data Scientist
# 26            Data Scientist - Applied Machine Learning
# 27                       Data Classification Specialist
# 28                                       Data Scientist
# 29                         Data Scientist - Entry Level
# ...                                                 ...
# 1561                                     Data Scientist
# 1562                              Data Scientist, Solar
# 1563                                     Data Scientist
# 1564                                     Data Scientist
# 1565                           Associate Data Scientist
# 1566                                     Data Scientist
# 1567                           Agronomic Data Scientist
# 1568                                     Data Scientist
# 1569              Data Scientist / Quantitative Analyst
# 1570                Advanced Analytics - Data Scientist
# 1571                         Staff Data Scientist - NLP
# 1572           Venture Capital Analyst - Data Scientist
# 1573  2020 Accelerated Development Program (ADP) IT ...
# 1574                                     Data Scientist
# 1575                          Data (Decision) Scientist
# 1576            Data Scientist – Computational Genetics
# 1577                                     Data Scientist
# 1578                                     Data Scientist
# 1579                                     Data Scientist
# 1580                                     Data Scientist
# 1581                                     DATA SCIENTIST
# 1582                                     Data Scientist
# 1583             Data Science Intern (BS / MS) - Intern
# 1584                                     Data Scientist
# 1585                        Data Scientist (Government)
# 1586                    Data Scientist - Incubation Lab
# 1587           Data Scientist/Machine Learning Engineer
# 1588                                   Sr. Data Analyst
# 1589                                Lead Data Scientist
# 1590                               Data Scientist - Hux
#
# [1591 rows x 4 columns]

# %%
data_scientist_job_df.to_csv("datascientistjobdata.csv", index=False)
